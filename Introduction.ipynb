# %%
from notebook.services.config import ConfigManager
cm = ConfigManager()
cm.update('livereveal', {
              'theme': 'solarized',
              'transition': 'zoom',
              'start_slideshow_at': 'selected',
})

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Turning Data Into Information
#
# * At the heart of the big data revolution
# * A very liberal arts thing to do -- Requires problem solving, **and** communication
# * Requires more than just a passing skill at querying the database

# %% [markdown]
# # Introduce Data Modeling
#
# * Key tool for communication
# * Describes the schema of the data -- the type or kinds of data, not the data itself
#
# | City |
# |---|
# | id |
# | name |
# | countrycode |
# | district |
# | population |
#
# | Country |
# |---|
# | code |
# | name |
# | continent |
# | region |
# | surfacearea |
# | indepyear |
# | population |
# | lifeexpectancy |
# | gnp |
# | gnpold |
# | localname |
# | governmentform |
# | headofstate |
# | capital |
# | code2 |

# %% [markdown]
# # Introduce Data Modeling
#
# * Describes relationships between things
#
# Country **has** City as a capital
#
# City **has** countrycode

# %% [markdown]
# # Relational Algebra
#
# ## Key Terms
#
# * Relation
#
# * Tuple
#
#   * A single row/record of a relation
#
# * Operators
#
# * Single-relation
#
#   * Project
#   * Select
#   * Sort
#   * Rename
#   * Extend
#   * Groupby
#
# * Two-relation
#
#   * Product
#   * Union
#   * Join
#   * Semijoin
#   * Antijoin
#   * Outer join
#
# **The result of applying an operator to a relation is another relation**
#
# [Luther JupyterHub](https://knuth.luther.edu:8443)

# %% [markdown]
# # A Relation with Country Data¶

# %% [markdown]
# Make new terminal and execute the following commands
#
# `mkdir cs140-notes`
#
# `cd cs140-notes`
#
# `cp /home/faculty/yasiro01/pub/city.csv .`
#
# `cp /home/faculty/yasiro01/pub/country.csv .`
#
# `logout`

# %%
from reframe import Relation
    
country = Relation('country.csv', sep='|')

# %%
country
# Out:
#     code                                          name      continent  \
# 0    AFG                                   Afghanistan           Asia
# 1    NLD                                   Netherlands         Europe
# 2    ANT                          Netherlands Antilles  North America
# 3    ALB                                       Albania         Europe
# 4    DZA                                       Algeria         Africa
# 5    ASM                                American Samoa        Oceania
# 6    AND                                       Andorra         Europe
# 7    AGO                                        Angola         Africa
# 8    AIA                                      Anguilla  North America
# 9    ATG                           Antigua and Barbuda  North America
# 10   ARE                          United Arab Emirates           Asia
# 11   ARG                                     Argentina  South America
# 12   ARM                                       Armenia           Asia
# 13   ABW                                         Aruba  North America
# 14   AUS                                     Australia        Oceania
# 15   AZE                                    Azerbaijan           Asia
# 16   BHS                                       Bahamas  North America
# 17   BHR                                       Bahrain           Asia
# 18   BGD                                    Bangladesh           Asia
# 19   BRB                                      Barbados  North America
# 20   BEL                                       Belgium         Europe
# 21   BLZ                                        Belize  North America
# 22   BEN                                         Benin         Africa
# 23   BMU                                       Bermuda  North America
# 24   BTN                                        Bhutan           Asia
# 25   BOL                                       Bolivia  South America
# 26   BIH                        Bosnia and Herzegovina         Europe
# 27   BWA                                      Botswana         Africa
# 28   BRA                                        Brazil  South America
# 29   GBR                                United Kingdom         Europe
# ..   ...                                           ...            ...
# 209  TUR                                        Turkey           Asia
# 210  TKM                                  Turkmenistan           Asia
# 211  TCA                      Turks and Caicos Islands  North America
# 212  TUV                                        Tuvalu        Oceania
# 213  UGA                                        Uganda         Africa
# 214  UKR                                       Ukraine         Europe
# 215  HUN                                       Hungary         Europe
# 216  URY                                       Uruguay  South America
# 217  NCL                                 New Caledonia        Oceania
# 218  NZL                                   New Zealand        Oceania
# 219  UZB                                    Uzbekistan           Asia
# 220  BLR                                       Belarus         Europe
# 221  WLF                             Wallis and Futuna        Oceania
# 222  VUT                                       Vanuatu        Oceania
# 223  VAT                 Holy See (Vatican City State)         Europe
# 224  VEN                                     Venezuela  South America
# 225  RUS                            Russian Federation         Europe
# 226  VNM                                       Vietnam           Asia
# 227  EST                                       Estonia         Europe
# 228  USA                                 United States  North America
# 229  VIR                          Virgin Islands, U.S.  North America
# 230  ZWE                                      Zimbabwe         Africa
# 231  PSE                                     Palestine           Asia
# 232  ATA                                    Antarctica     Antarctica
# 233  BVT                                 Bouvet Island     Antarctica
# 234  IOT                British Indian Ocean Territory         Africa
# 235  SGS  South Georgia and the South Sandwich Islands     Antarctica
# 236  HMD             Heard Island and McDonald Islands     Antarctica
# 237  ATF                   French Southern territories     Antarctica
# 238  UMI          United States Minor Outlying Islands        Oceania
#
#                         region  surfacearea  indepyear  population  \
# 0    Southern and Central Asia     652090.0     1919.0    22720000
# 1               Western Europe      41526.0     1581.0    15864000
# 2                    Caribbean        800.0        NaN      217000
# 3              Southern Europe      28748.0     1912.0     3401200
# 4              Northern Africa    2381740.0     1962.0    31471000
# 5                    Polynesia        199.0        NaN       68000
# 6              Southern Europe        468.0     1278.0       78000
# 7               Central Africa    1246700.0     1975.0    12878000
# 8                    Caribbean         96.0        NaN        8000
# 9                    Caribbean        442.0     1981.0       68000
# 10                 Middle East      83600.0     1971.0     2441000
# 11               South America    2780400.0     1816.0    37032000
# 12                 Middle East      29800.0     1991.0     3520000
# 13                   Caribbean        193.0        NaN      103000
# 14   Australia and New Zealand    7741220.0     1901.0    18886000
# 15                 Middle East      86600.0     1991.0     7734000
# 16                   Caribbean      13878.0     1973.0      307000
# 17                 Middle East        694.0     1971.0      617000
# 18   Southern and Central Asia     143998.0     1971.0   129155000
# 19                   Caribbean        430.0     1966.0      270000
# 20              Western Europe      30518.0     1830.0    10239000
# 21             Central America      22696.0     1981.0      241000
# 22              Western Africa     112622.0     1960.0     6097000
# 23               North America         53.0        NaN       65000
# 24   Southern and Central Asia      47000.0     1910.0     2124000
# 25               South America    1098580.0     1825.0     8329000
# 26             Southern Europe      51197.0     1992.0     3972000
# 27             Southern Africa     581730.0     1966.0     1622000
# 28               South America    8547400.0     1822.0   170115000
# 29             British Islands     242900.0     1066.0    59623400
# ..                         ...          ...        ...         ...
# 209                Middle East     774815.0     1923.0    66591000
# 210  Southern and Central Asia     488100.0     1991.0     4459000
# 211                  Caribbean        430.0        NaN       17000
# 212                  Polynesia         26.0     1978.0       12000
# 213             Eastern Africa     241038.0     1962.0    21778000
# 214             Eastern Europe     603700.0     1991.0    50456000
# 215             Eastern Europe      93030.0     1918.0    10043200
# 216              South America     175016.0     1828.0     3337000
# 217                  Melanesia      18575.0        NaN      214000
# 218  Australia and New Zealand     270534.0     1907.0     3862000
# 219  Southern and Central Asia     447400.0     1991.0    24318000
# 220             Eastern Europe     207600.0     1991.0    10236000
# 221                  Polynesia        200.0        NaN       15000
# 222                  Melanesia      12189.0     1980.0      190000
# 223            Southern Europe          0.4     1929.0        1000
# 224              South America     912050.0     1811.0    24170000
# 225             Eastern Europe   17075400.0     1991.0   146934000
# 226             Southeast Asia     331689.0     1945.0    79832000
# 227           Baltic Countries      45227.0     1991.0     1439200
# 228              North America    9363520.0     1776.0   278357000
# 229                  Caribbean        347.0        NaN       93000
# 230             Eastern Africa     390757.0     1980.0    11669000
# 231                Middle East       6257.0        NaN     3101000
# 232                 Antarctica   13120000.0        NaN           0
# 233                 Antarctica         59.0        NaN           0
# 234             Eastern Africa         78.0        NaN           0
# 235                 Antarctica       3903.0        NaN           0
# 236                 Antarctica        359.0        NaN           0
# 237                 Antarctica       7780.0        NaN           0
# 238       Micronesia/Caribbean         16.0        NaN           0
#
#      lifeexpectancy        gnp     gnpold  \
# 0              45.9     5976.0        NaN
# 1              78.3   371362.0   360478.0
# 2              74.7     1941.0        NaN
# 3              71.6     3205.0     2500.0
# 4              69.7    49982.0    46966.0
# 5              75.1      334.0        NaN
# 6              83.5     1630.0        NaN
# 7              38.3     6648.0     7984.0
# 8              76.1       63.2        NaN
# 9              70.5      612.0      584.0
# 10             74.1    37966.0    36846.0
# 11             75.1   340238.0   323310.0
# 12             66.4     1813.0     1627.0
# 13             78.4      828.0      793.0
# 14             79.8   351182.0   392911.0
# 15             62.9     4127.0     4100.0
# 16             71.1     3527.0     3347.0
# 17             73.0     6366.0     6097.0
# 18             60.2    32852.0    31966.0
# 19             73.0     2223.0     2186.0
# 20             77.8   249704.0   243948.0
# 21             70.9      630.0      616.0
# 22             50.2     2357.0     2141.0
# 23             76.9     2328.0     2190.0
# 24             52.4      372.0      383.0
# 25             63.7     8571.0     7967.0
# 26             71.5     2841.0        NaN
# 27             39.3     4834.0     4935.0
# 28             62.9   776739.0   804108.0
# 29             77.7  1378330.0  1296830.0
# ..              ...        ...        ...
# 209            71.0   210721.0   189122.0
# 210            60.9     4397.0     2000.0
# 211            73.3       96.0        NaN
# 212            66.3        6.0        NaN
# 213            42.9     6313.0     6887.0
# 214            66.0    42168.0    49677.0
# 215            71.4    48267.0    45914.0
# 216            75.2    20831.0    19967.0
# 217            72.8     3563.0        NaN
# 218            77.8    54669.0    64960.0
# 219            63.7    14194.0    21300.0
# 220            68.0    13714.0        NaN
# 221             NaN        0.0        NaN
# 222            60.6      261.0      246.0
# 223             NaN        9.0        NaN
# 224            73.1    95023.0    88434.0
# 225            67.2   276608.0   442989.0
# 226            69.3    21929.0    22834.0
# 227            69.5     5328.0     3371.0
# 228            77.1  8510700.0  8110900.0
# 229            78.1        0.0        NaN
# 230            37.8     5951.0     8670.0
# 231            71.4     4173.0        NaN
# 232             NaN        0.0        NaN
# 233             NaN        0.0        NaN
# 234             NaN        0.0        NaN
# 235             NaN        0.0        NaN
# 236             NaN        0.0        NaN
# 237             NaN        0.0        NaN
# 238             NaN        0.0        NaN
#
#                                         localname  \
# 0                           Afganistan/Afqanestan
# 1                                       Nederland
# 2                            Nederlandse Antillen
# 3                                       Shqipëria
# 4                              Al-Jazair/Algérie
# 5                                   Amerika Samoa
# 6                                         Andorra
# 7                                          Angola
# 8                                        Anguilla
# 9                             Antigua and Barbuda
# 10             Al-Imarat al-´Arabiya al-Muttahida
# 11                                      Argentina
# 12                                       Hajastan
# 13                                          Aruba
# 14                                      Australia
# 15                                     Azärbaycan
# 16                                    The Bahamas
# 17                                     Al-Bahrayn
# 18                                     Bangladesh
# 19                                       Barbados
# 20                                België/Belgique
# 21                                         Belize
# 22                                          Bénin
# 23                                        Bermuda
# 24                                       Druk-Yul
# 25                                        Bolivia
# 26                            Bosna i Hercegovina
# 27                                       Botswana
# 28                                         Brasil
# 29                                 United Kingdom
# ..                                            ...
# 209                                       Türkiye
# 210                                  Türkmenostan
# 211                  The Turks and Caicos Islands
# 212                                        Tuvalu
# 213                                        Uganda
# 214                                      Ukrajina
# 215                                  Magyarország
# 216                                       Uruguay
# 217                            Nouvelle-Calédonie
# 218                          New Zealand/Aotearoa
# 219                                    Uzbekiston
# 220                                       Belarus
# 221                              Wallis-et-Futuna
# 222                                       Vanuatu
# 223                 Santa Sede/Città del Vaticano
# 224                                     Venezuela
# 225                                       Rossija
# 226                                      Viêt Nam
# 227                                         Eesti
# 228                                 United States
# 229           Virgin Islands of the United States
# 230                                      Zimbabwe
# 231                                      Filastin
# 232                                             
# 233                                     Bouvetøya
# 234                British Indian Ocean Territory
# 235  South Georgia and the South Sandwich Islands
# 236                    Heard and McDonald Islands
# 237                   Terres australes françaises
# 238          United States Minor Outlying Islands
#
#                                    governmentform  \
# 0                                 Islamic Emirate
# 1                         Constitutional Monarchy
# 2    Nonmetropolitan Territory of The Netherlands
# 3                                        Republic
# 4                                        Republic
# 5                                    US Territory
# 6                    Parliamentary Coprincipality
# 7                                        Republic
# 8                   Dependent Territory of the UK
# 9                         Constitutional Monarchy
# 10                             Emirate Federation
# 11                               Federal Republic
# 12                                       Republic
# 13   Nonmetropolitan Territory of The Netherlands
# 14            Constitutional Monarchy, Federation
# 15                               Federal Republic
# 16                        Constitutional Monarchy
# 17                             Monarchy (Emirate)
# 18                                       Republic
# 19                        Constitutional Monarchy
# 20            Constitutional Monarchy, Federation
# 21                        Constitutional Monarchy
# 22                                       Republic
# 23                  Dependent Territory of the UK
# 24                                       Monarchy
# 25                                       Republic
# 26                               Federal Republic
# 27                                       Republic
# 28                               Federal Republic
# 29                        Constitutional Monarchy
# ..                                            ...
# 209                                      Republic
# 210                                      Republic
# 211                 Dependent Territory of the UK
# 212                       Constitutional Monarchy
# 213                                      Republic
# 214                                      Republic
# 215                                      Republic
# 216                                      Republic
# 217           Nonmetropolitan Territory of France
# 218                       Constitutional Monarchy
# 219                                      Republic
# 220                                      Republic
# 221           Nonmetropolitan Territory of France
# 222                                      Republic
# 223                      Independent Church State
# 224                              Federal Republic
# 225                              Federal Republic
# 226                          Socialistic Republic
# 227                                      Republic
# 228                              Federal Republic
# 229                                  US Territory
# 230                                      Republic
# 231                               Autonomous Area
# 232                              Co-administrated
# 233                 Dependent Territory of Norway
# 234                 Dependent Territory of the UK
# 235                 Dependent Territory of the UK
# 236                        Territory of Australia
# 237           Nonmetropolitan Territory of France
# 238                 Dependent Territory of the US
#
#                      headofstate  capital code2
# 0                  Mohammad Omar      1.0    AF
# 1                        Beatrix      5.0    NL
# 2                        Beatrix     33.0    AN
# 3                 Rexhep Mejdani     34.0    AL
# 4           Abdelaziz Bouteflika     35.0    DZ
# 5                 George W. Bush     54.0    AS
# 6                            NaN     55.0    AD
# 7        José Eduardo dos Santos     56.0    AO
# 8                   Elisabeth II     62.0    AI
# 9                   Elisabeth II     63.0    AG
# 10   Zayid bin Sultan al-Nahayan     65.0    AE
# 11            Fernando de la Rúa     69.0    AR
# 12              Robert Kotarjan    126.0    AM
# 13                       Beatrix    129.0    AW
# 14                  Elisabeth II    135.0    AU
# 15                 Heydär Äliyev    144.0    AZ
# 16                  Elisabeth II    148.0    BS
# 17      Hamad ibn Isa al-Khalifa    149.0    BH
# 18             Shahabuddin Ahmad    150.0    BD
# 19                  Elisabeth II    174.0    BB
# 20                     Albert II    179.0    BE
# 21                  Elisabeth II    185.0    BZ
# 22               Mathieu Kérékou    187.0    BJ
# 23                  Elisabeth II    191.0    BM
# 24         Jigme Singye Wangchuk    192.0    BT
# 25            Hugo Bánzer Suárez    194.0    BO
# 26                  Ante Jelavic    201.0    BA
# 27               Festus G. Mogae    204.0    BW
# 28     Fernando Henrique Cardoso    211.0    BR
# 29                  Elisabeth II    456.0    GB
# ..                           ...      ...   ...
# 209           Ahmet Necdet Sezer   3358.0    TR
# 210           Saparmurad Nijazov   3419.0    TM
# 211                 Elisabeth II   3423.0    TC
# 212                 Elisabeth II   3424.0    TV
# 213              Yoweri Museveni   3425.0    UG
# 214                Leonid Kutma   3426.0    UA
# 215                  Ferenc Mádl   3483.0    HU
# 216          Jorge Batlle Ibáñez   3492.0    UY
# 217               Jacques Chirac   3493.0    NC
# 218                 Elisabeth II   3499.0    NZ
# 219                Islam Karimov   3503.0    UZ
# 220         Aljaksandr Lukaenka   3520.0    BY
# 221               Jacques Chirac   3536.0    WF
# 222                    John Bani   3537.0    VU
# 223          Johannes Paavali II   3538.0    VA
# 224            Hugo Chávez Frías   3539.0    VE
# 225               Vladimir Putin   3580.0    RU
# 226               Trân Duc Luong   3770.0    VN
# 227                 Lennart Meri   3791.0    EE
# 228               George W. Bush   3813.0    US
# 229               George W. Bush   4067.0    VI
# 230             Robert G. Mugabe   4068.0    ZW
# 231        Yasser (Yasir) Arafat   4074.0    PS
# 232                          NaN      NaN    AQ
# 233                     Harald V      NaN    BV
# 234                 Elisabeth II      NaN    IO
# 235                 Elisabeth II      NaN    GS
# 236                 Elisabeth II      NaN    HM
# 237               Jacques Chirac      NaN    TF
# 238               George W. Bush      NaN    UM
#
# [239 rows x 15 columns]

# %%
country.head()
# Out:
#   code                  name      continent                     region  \
# 0  AFG           Afghanistan           Asia  Southern and Central Asia
# 1  NLD           Netherlands         Europe             Western Europe
# 2  ANT  Netherlands Antilles  North America                  Caribbean
# 3  ALB               Albania         Europe            Southern Europe
# 4  DZA               Algeria         Africa            Northern Africa
#
#    surfacearea  indepyear  population  lifeexpectancy       gnp    gnpold  \
# 0     652090.0     1919.0    22720000            45.9    5976.0       NaN
# 1      41526.0     1581.0    15864000            78.3  371362.0  360478.0
# 2        800.0        NaN      217000            74.7    1941.0       NaN
# 3      28748.0     1912.0     3401200            71.6    3205.0    2500.0
# 4    2381740.0     1962.0    31471000            69.7   49982.0   46966.0
#
#                localname                                governmentform  \
# 0  Afganistan/Afqanestan                               Islamic Emirate
# 1              Nederland                       Constitutional Monarchy
# 2   Nederlandse Antillen  Nonmetropolitan Territory of The Netherlands
# 3              Shqipëria                                      Republic
# 4     Al-Jazair/Algérie                                      Republic
#
#             headofstate  capital code2
# 0         Mohammad Omar      1.0    AF
# 1               Beatrix      5.0    NL
# 2               Beatrix     33.0    AN
# 3        Rexhep Mejdani     34.0    AL
# 4  Abdelaziz Bouteflika     35.0    DZ

# %%
country.head(1)
# Out:
#   code         name continent                     region  surfacearea  \
# 0  AFG  Afghanistan      Asia  Southern and Central Asia     652090.0
#
#    indepyear  population  lifeexpectancy     gnp  gnpold  \
# 0     1919.0    22720000            45.9  5976.0     NaN
#
#                localname   governmentform    headofstate  capital code2
# 0  Afganistan/Afqanestan  Islamic Emirate  Mohammad Omar      1.0    AF

# %% [markdown]
# # Relational Algebra: Project

# %%
country.project(['name', 'indepyear', 'population']).head()
# Out:
#                    name  indepyear  population
# 0           Afghanistan     1919.0    22720000
# 1           Netherlands     1581.0    15864000
# 2  Netherlands Antilles        NaN      217000
# 3               Albania     1912.0     3401200
# 4               Algeria     1962.0    31471000

# %% [markdown]
# # Relational Algebra: Select

# %%
country.query('indepyear < 1200')
# Out:
#     code            name continent            region  surfacearea  indepyear  \
# 29   GBR  United Kingdom    Europe   British Islands     242900.0     1066.0
# 48   ETH        Ethiopia    Africa    Eastern Africa    1104300.0    -1000.0
# 81   JPN           Japan      Asia      Eastern Asia     377829.0     -660.0
# 93   CHN           China      Asia      Eastern Asia    9572900.0    -1523.0
# 159  PRT        Portugal    Europe   Southern Europe      91982.0     1143.0
# 164  FRA          France    Europe    Western Europe     551500.0      843.0
# 170  SWE          Sweden    Europe  Nordic Countries     449964.0      836.0
# 180  SMR      San Marino    Europe   Southern Europe         61.0      885.0
# 200  DNK         Denmark    Europe  Nordic Countries      43094.0      800.0
#
#      population  lifeexpectancy        gnp     gnpold       localname  \
# 29     59623400            77.7  1378330.0  1296830.0  United Kingdom
# 48     62565000            45.2     6353.0     6180.0     YeItyop´iya
# 81    126714000            80.7  3787042.0  4192638.0    Nihon/Nippon
# 93   1277558000            71.4   982268.0   917719.0        Zhongquo
# 159     9997600            75.8   105954.0   102133.0        Portugal
# 164    59225700            78.8  1424285.0  1392448.0          France
# 170     8861400            79.6   226492.0   227757.0         Sverige
# 180       27000            81.1      510.0        NaN      San Marino
# 200     5330000            76.5   174099.0   169264.0         Danmark
#
#               governmentform      headofstate  capital code2
# 29   Constitutional Monarchy     Elisabeth II    456.0    GB
# 48                  Republic   Negasso Gidada    756.0    ET
# 81   Constitutional Monarchy          Akihito   1532.0    JP
# 93          People'sRepublic      Jiang Zemin   1891.0    CN
# 159                 Republic    Jorge Sampãio   2914.0    PT
# 164                 Republic   Jacques Chirac   2974.0    FR
# 170  Constitutional Monarchy  Carl XVI Gustaf   3048.0    SE
# 180                 Republic              NaN   3171.0    SM
# 200  Constitutional Monarchy     Margrethe II   3315.0    DK

# %%
country.project(['name', 'indepyear']).query('indepyear < 1200')
# Out:
#                name  indepyear
# 29   United Kingdom     1066.0
# 48         Ethiopia    -1000.0
# 81            Japan     -660.0
# 93            China    -1523.0
# 159        Portugal     1143.0
# 164          France      843.0
# 170          Sweden      836.0
# 180      San Marino      885.0
# 200         Denmark      800.0

# %%
country.query('indepyear < 1200').project(['name', 'indepyear'])
# Out:
#                name  indepyear
# 29   United Kingdom     1066.0
# 48         Ethiopia    -1000.0
# 81            Japan     -660.0
# 93            China    -1523.0
# 159        Portugal     1143.0
# 164          France      843.0
# 170          Sweden      836.0
# 180      San Marino      885.0
# 200         Denmark      800.0

# %% [markdown]
# # Relational Algebra: Sort

# %%
country.query('indepyear < 1200').project(['name', 'indepyear']).sort(['indepyear'])
# Out:
#                name  indepyear
# 93            China    -1523.0
# 48         Ethiopia    -1000.0
# 81            Japan     -660.0
# 200         Denmark      800.0
# 170          Sweden      836.0
# 164          France      843.0
# 180      San Marino      885.0
# 29   United Kingdom     1066.0
# 159        Portugal     1143.0

# %%
country.query('indepyear < 1200').project(['name', 'indepyear']).sort(['indepyear'], ascending=False)
# Out:
#                name  indepyear
# 159        Portugal     1143.0
# 29   United Kingdom     1066.0
# 180      San Marino      885.0
# 164          France      843.0
# 170          Sweden      836.0
# 200         Denmark      800.0
# 81            Japan     -660.0
# 48         Ethiopia    -1000.0
# 93            China    -1523.0

# %% [markdown]
# # SQL: Structured Query Language

# %% [markdown]
# # SQL
#
# SQL is the language of database management systems
# Database Management System (DBMS) provides:
#
# * efficient
# * reliable
# * convenient
# * safe
# * multi-user
#
# storage of and access to massive amounts of persistent data
#
# Many Database management systems are built on the relational model
#
# * Postgresql, MySQL, SQLLITE
#
# Relation == Table
#
# Tuple == Row

# %%
# %load_ext sql
